# %% [markdown]
# # S3 — Build the SPN feature table

# %%
from pathlib import Path
import os, sys, pandas as pd
ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
sys.path.insert(0, str(ROOT))
EVENTS_DIR, F360_DIR, OUTPUT_DIR = Path(os.environ['EVENTS_DIR']), Path(os.environ['F360_DIR']), Path(os.environ['OUTPUT_DIR'])
labels = pd.read_csv(OUTPUT_DIR / 'labels.csv')

# %%
from src.spn_features import SPN_ALL_FEATURES, build_spn_feature_table, save_feature_table
from src.spn_network import PressureParams

# Keep this definition aligned with S1 when reproducing the main specification.
PRESSURE_PARAMS = PressureParams(player_distance=6.4, player_sd=2.2, boundary_distance=3.2, boundary_sd=1.1)
features = build_spn_feature_table(labels, EVENTS_DIR, F360_DIR, params=PRESSURE_PARAMS)
feature_path = save_feature_table(features, OUTPUT_DIR)
display(features[SPN_ALL_FEATURES].describe().T)
print('Saved:', feature_path)
